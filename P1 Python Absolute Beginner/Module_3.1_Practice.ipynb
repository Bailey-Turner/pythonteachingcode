# %% [markdown]
# # P1M3: Module 3 Practice
# ## Conditionals
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - **control code flow with `if`... `else` conditional logic**
#   - using Boolean string methods (`.isupper(), .isalpha(), .startswith()...`)
#   - using comparision (`>, <, >=, <=, ==, !=`)
#   - using Strings in comparisons
#
# ## `if else`

# %%
# [ ] input a variable: age as digit and cast to int
# if age greater than or equal to 12 then print message on age in 10 years 
# or else print message "It is good to be" age
age = int(input("Input your age (use only whole numbers): "))
print("Age's first type is: ",type(age))
age = int(age)
print("Age's second type is: ",type(age))

if age >= 12:
    print("In ten years you will be "+str(age+10)+".")
else:
    print("It is good to be "+str(age)+".")
# Out:
# Age's first type is:  <class 'int'>
# Age's second type is:  <class 'int'>
# In ten years you will be 30.

# %%
# [ ] input a number 
# if number IS a digit string then cast to int
# print number "greater than 100 is" True/False
# if number is NOT a digit string then message the user that "only int is accepted"

number = input("Input a number: ")
if number.isdigit():
    number = int(number)
    print(number, "greater than 100 is", number > 100)
else:
    print("Only int is accepted.")
# Out:
# Only int is accepted.

# %% [markdown]
# ### Guessing a letter A-Z
# **check_guess()** takes 2 string arguments: **letter and guess** (both expect single alphabetical character)
#     - if guess is not an alpha character print invalid and return False
#     - test and print if guess is "high" or "low" and return False
#     - test and print if guess is "correct" and return True

# %%
# [ ] create check_guess()
def check_guess(letter,guess):
    guess = str(guess)
    if guess.isalpha():
        #guess is alphabetical letters
        if len(guess)==1:
            #guess is one character
            #TODO check the guess
            if guess == letter:
                print("Correct")
                return True
            elif guess > letter:
                print("Low")
                return False
            elif guess < letter:
                print("High")
                return False
            else:
                print("unhandled exception")
                return False
        else:
            print("Invalid - more than one character")
            return False
    else:
        print("Invalid - not alphabetical")
        return False
    
def letter_game(correct_answer):
    this_guess = input("Guess the letter (provide one letter): ")
    if True == check_guess(correct_answer,this_guess):
        print("On the first try! What a mensch.")
    else:
        #second guess
        this_guess = input("Guess the letter (provide one letter): ")
        if True == check_guess(correct_answer,this_guess):
            print("On the second try! What a mensch.")
        else:
        #third guess
            this_guess = input("Guess the letter (provide one letter): ")
            if True == check_guess(correct_answer,this_guess):
                print("On the third try! Sortta slow.")
            else:
                print("You lose.")

letter_game("A")
# Out:
# Low
# Correct
# On the second try! What a mensch.

# %%
# [ ] call check_guess with user input
letter = input("Input a letter: ")
guess = input("Input a guess: ")
check_guess(letter,guess)
# Out:
# Low
# False

# %% [markdown]
# ### Letter Guess
# **create letter_guess() function that gives user 3 guesses**
# - takes a letter character argument for the answer letter
# - gets user input for letter guess
# - calls check_guess() with answer and guess
# - End letter_guess if
#     - check_guess() equals True, return True
#     - or after 3 failed attempts, return False

# %%
# [ ] create letter_guess() function, call the function to test
def letter_guess():
    correct_answer = "A"
    this_guess = input("Guess the letter (provide one letter): ")
    if True == check_guess(correct_answer,this_guess):
        return True
    else:
        #second guess
        this_guess = input("Guess the letter (provide one letter): ")
        if True == check_guess(correct_answer,this_guess):
            return True
        else:
        #third guess
            this_guess = input("Guess the letter (provide one letter): ")
            if True == check_guess(correct_answer,this_guess):
                return True
            else:
                return False
letter_guess()
# Out:
# Low
# Low
# Correct
# True

# %% [markdown]
# ### Pet Conversation
# **ask the user for a sentence about a pet and then reply**
# - get user input in variable: about_pet
# - using a series of **if** statements respond with appropriate conversation
#   - check if "dog" is in the string about_pet (sample reply "Ah, a dog")
#   - check if "cat" is in the string about_pet
#   - check if 1 or more animal is in string about_pet
# - no need for **else**'s
# - finish with thanking for the story

# %%
# [ ] complete pet conversation
about_pet = input("What kind of pet do you have? ")
if about_pet.isalpha():
    about_pet = about_pet.lower()
    if about_pet == "dog":
        print("Dogs are great! I have a dog named Fido.")
    elif about_pet == "cat":
        print("Cats are great! I have a cat named Felix.")
    elif about_pet == "hamster":
        print("Hamsters are great! I have a hamster named Hammy.")


print("Thank you for sharing about your pet!")
# Out:
# Dogs are great! I have a dog named Fido.
# Thank you for sharing about your pet!

# %% [markdown]
# # Module 3 Practice 2
# ## conditionals, type, and mathematics extended
# &nbsp;
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - code more than two choices using **`elif`**
# - gather numeric input using type casting
# - perform subtraction, multiplication and division operations in code  &nbsp;

# %% [markdown]
# # &nbsp;
# <font size="6" color="#B24C00"  face="verdana"> <B>Tasks</B></font>

# %% [markdown]
# ### Rainbow colors
# ask for input of a favorite rainbow color first letter: ROYGBIV
#
# Using `if`, `elif`, and `else`:
# - print the color matching the letter
#     - R = Red
#     - O = Orange
#     - Y = Yellow
#     - G = Green
#     - B = Blue
#     - I = Indigo
#     - V = Violet
#     - else print "no match"

# %%
# [ ] complete rainbow colors
rainbow_color = input("What is your favorite rainbow color? Select one of the following letters: R, O, Y, G, B, I, V  ")
R = "Red"
O = "Orange"
Y = "Yellow"
G = "Green"
B = "Blue"
I = "Indigo"
V = "Violet"
if rainbow_color.upper() == "R":
    print(R)
elif rainbow_color.upper() == "O":
    print(O)
elif rainbow_color.upper() == "Y":
    print(Y)
elif rainbow_color.upper() == "G":
    print(G)
elif rainbow_color.upper() == "B":
    print(B)
elif rainbow_color.upper() == "I":
    print(I)
elif rainbow_color.upper() == "V":
    print(V)
else:
    print("no match")
# Out:
# Orange

# %%
# [ ] make the code above into a function rainbow_color() that has a string parameter, 
# get input and call the function and return the matching color as a string or "no match" message.
# Call the function and print the return string.
def rainbow_color(fav_color):
    R = "Red"
    O = "Orange"
    Y = "Yellow"
    G = "Green"
    B = "Blue"
    I = "Indigo"
    V = "Violet"
    if fav_color.upper() == "R":
        return R
    elif fav_color.upper() == "O":
        return O
    elif fav_color.upper() == "Y":
        return Y
    elif fav_color.upper() == "G":
        return G
    elif fav_color.upper() == "B":
        return B
    elif fav_color.upper() == "I":
        return I
    elif fav_color.upper() == "V":
        return V
    else:
        return "no match"
    
fav_color = input("What is your favorite rainbow color? Select one of the following letters: R, O, Y, G, B, I, V  ")
print(rainbow_color(fav_color))
# Out:
# Indigo

# %% [markdown]
# # &nbsp;
# **Create function age_20() that adds or subtracts 20 from your age for a return value based on current age** (use `if`)
# - call the funtion with user input and then use the return value in a sentence
# example `age_20(25)` returns **5**:
# > "5 years old, 20 years difference from now"

# %%
# [ ] complete age_20()
def age_20(age):
    if age >= 20:
        difference = age - 20
    else:
        difference = age + 20
    return difference
age = int(input("Input your age (use only whole numbers): "))
print(str(age_20(age)) + " years old, 20 years difference from now.")
# Out:
# 35 years old, 20 years difference from now.

# %% [markdown]
# **create a function rainbow_or_age that takes a string argument**
# - if argument is a digit return the value of calling age_20() with the str value cast as **`int`**
# - if argument is an alphabetical character return the value of calling rainbow_color() with the str
# - if neither return FALSE

# %%
# [ ]  create rainbow_or_age()
def rainbow_or_age(value):
    if value.isdigit():
        return age_20(int(value))
    elif value.isalpha():
        return rainbow_color(value)
    else:
        return False

# %%
# [ ]  add 2 numbers from input using a cast to integer and display the answer 
num1 = input("Enter a number to add: ")
num2 = input("Enter another number to add: ")

total = int(num1) + int(num2)
print("The total is:", total)
# Out:
# The total is: 12

# %%
# [ ] Multiply 2 numbers from input using cast and save the answer as part of a string "the answer is..."
# display the string using print
num1 = input("Enter a number to multiply: ")
num2 = input("Enter another number to multiply: ")

product = int(num1) * int(num2)
result_string = "The answer is: " + str(product)
print(result_string)
# Out:
# The answer is: 35

# %%
# [ ] get input of 2 numbers and display the average: (num1 + num2) divided by 2
num1 = input("Enter a number: ")
num2 = input("Enter another number: ")
average = (int(num1) + int(num2)) / 2
print("The average is:", average)
# Out:
# The average is: 71.5

# %%
# [ ] get input of 2 numbers and subtract the largest from the smallest (use an if statement to see which is larger)
# show the answer
num1 = input("Enter a number: ")
num2 = input("Enter another number: ")
if int(num1) > int(num2):
    difference = int(num2) - int(num1)
else:
    difference = int(num1) - int(num2)
print("The difference is:", difference)
# Out:
# The difference is: -96

# %%
# [ ] Divide a larger number by a smaller number and print the integer part of the result
# don't divide by zero! if a zero is input make the result zero
# [ ] cast the answer to an integer to cut off the decimals and print the result
num1 = input("Enter a number: ")
num2 = input("Enter another number: ")
if int(num1) == 0 or int(num2) == 0:
    result = 0
elif int(num1) > int(num2):
    result = int(num1) / int(num2)
else:    result = int(num2) / int(num1)
print("The integer part of the result is:", int(result))
# Out:
# The integer part of the result is: 16

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
